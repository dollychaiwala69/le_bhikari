# %%
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Load Iris Dataset
iris = datasets.load_iris()
X = iris.data

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
def k_means_clustering(X, k_values):
    for k in k_values:
        # Initialize K-Means
        kmeans = KMeans(n_clusters=k, random_state=42)

        # Fit and predict clusters
        y_kmeans = kmeans.fit_predict(X)

        # Compute silhouette score
        silhouette_avg = silhouette_score(X, y_kmeans)

        # Print output ONLY
        print(f"For K={k}, the silhouette score is: {silhouette_avg:.2f}")

# %%
k_values = [2, 3, 4, 5]

k_means_clustering(X_scaled, k_values)
# Out:
# For K=2, the silhouette score is: 0.58
# For K=3, the silhouette score is: 0.48
# For K=4, the silhouette score is: 0.39
# For K=5, the silhouette score is: 0.35
